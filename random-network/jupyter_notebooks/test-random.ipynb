# %%
import networkx as nx
import matplotlib as mpl
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
import pandas as pd
import pickle
from scipy.stats import poisson

# %%
import ordpy
# %run ./ordpy.py

# %%
# G = nx.gnp_random_graph(1000, .002)
# nx.write_gml(G, 'random-1.gml')
G = nx.read_gml('random-1.gml')

# %%
# G_2 = nx.gnp_random_graph(10000, .0015)
# nx.write_gml(G_2,'random-10.gml')
G_2 = nx.read_gml('random-10.gml')

# %%
G_3 = nx.gnp_random_graph(100, .15)
short_path_3 = nx.average_shortest_path_length(G_3)

# %%
nx.write_gml(G_3,'random-100.gml')

# %%
# y_3 = np.log10(np.mean([x[1] for x in list(G_3.degree())]))*short_path_3

# with open('data/y_3.pkl' , 'wb') as file:
#     pickle.dump(y_3, file)

with open('data/y_3.pkl', 'rb') as file:
    y_3 = pickle.load(file)

# %%
# short_path = nx.average_shortest_path_length(G_2)
# nx.write_gpickle(short_path, 'short_path.gml')
short_path = nx.read_gpickle('short_path.gml')

# %%
# y = np.log10(np.mean([x[1] for x in list(G_2.degree())]))*short_path

# with open ('data/y.pkl', 'wb') as file:
#     pickle.dump(y, file)

with open ('data/y.pkl', 'rb') as file:
    y = pickle.load(file)

# %%
# np.mean([x[1] for x in list(G_2.degree())])
# Out:
# 14.9236

# %%
# short_path_2 = nx.average_shortest_path_length(G)

# %%
# y_2 = np.log(np.mean([x[1] for x in list(G.degree())]))*short_path_2

# %%
x_line = [G_3.number_of_nodes() ,G_2.number_of_nodes()]
y_line = [y_3, y] 
fig, ax = plt.subplots()


# Infinite black line going through (0, 0) to (1, 1).
ax_dict['B'].axline(xy1 = (x_line[0], y_line[0]), xy2=(x_line[1] , y_line[1]), color='C0', label='by slope', linestyle='--')
ax.set_xlim(1, 100000000)
ax.set_ylim(0, 15)
ax.set_xticks([1, 100, 10000, 1000000, 100000000])
ax.set_yticks([0, 5, 10 ,15])
ax.set_xscale('log')
ax.set_title("Degree Rank Plot")
ax.set_ylabel("Degree")
ax.set_xlabel("Rank")
plt.show()

# %%
f, ax   = plt.subplots(ncols=1, nrows=2, figsize=stdfigsize(ncols=1, nrows=2))
# f = plt.figure(figsize = stdfigsize(nrows=2, ncols=2))
# axgrid = f.add_gridspec(5, 4)
x_line = [G_3.number_of_nodes() ,G_2.number_of_nodes()]
y_line = [y_3, y] 
# ax = f.add_subplot(axgrid[1:3, :])
# def connectpoints(x,y,p1,p2):
#     x1, x2 = x[p1], x[p2]
#     y1, y2 = y[p1], y[p2]
#     ax.plot([x1,x2],[y1,y2],'k--')
# connectpoints(x_line,y_line,0,1)

# ax[0].plot(x_line, y_line, linestyle='--')
# ax[0].set_xscale('log')
# ax[0].set_yscale('linear')
# ax.set_xlim(1, 100000000)
# ax[0].set_ylim(auto = None, ymin=0, ymax=15)
# slope, intercept = np.polyfit(np.log(x_line), np.log(y_line), 1)
# print(slope)
# ax[0].set_xticks([1, 100, 10000])
# ax[0].set_yticks([0, 5, 10 ,15])

# ax2 = f.add_subplot(axgrid[2, 2])
ax[0].axline(xy1 = (x_line[0], y_line[0]), xy2=(x_line[1] , y_line[1]), color='C0', label='by slope', linestyle='--')
ax[0].set_xlim(1, 100000000)
ax[0].set_ylim(0, 15)
ax[0].set_xticks([1, 100, 10000, 1000000, 100000000])
ax[0].set_yticks([0, 5, 10 ,15])
ax[0].set_xscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 4
#       1 f, ax   = plt.subplots(ncols=1, nrows=2, figsize=stdfigsize(ncols=1, nrows=2))
#       2 # f = plt.figure(figsize = stdfigsize(nrows=2, ncols=2))
#       3 # axgrid = f.add_gridspec(5, 4)
# ----> 4 x_line = [G_3.number_of_nodes() ,G_2.number_of_nodes()]
#       5 y_line = [y_3, y]
#       6 # ax = f.add_subplot(axgrid[1:3, :])
#       7 # def connectpoints(x,y,p1,p2):
#       8 #     x1, x2 = x[p1], x[p2]
#    (...)
#      22
#      23 # ax2 = f.add_subplot(axgrid[2, 2])
#
# NameError: name 'G_3' is not defined

# %%
degree_sequence = sorted((d for n, d in G.degree()), reverse=True)
dmax = max(degree_sequence)

fig = plt.figure("Degree of a random graph", figsize=stdfigsize(nrows=2, ncols=2))
# Create a gridspec for adding subplots of different sizes
axgrid = fig.add_gridspec(5, 4)

ax0 = fig.add_subplot(axgrid[0:3, :])
Gcc = G.subgraph(sorted(nx.connected_components(G), key=len, reverse=True)[0])
# pos = nx.kamada_kawai_layout(Gcc, seed=10396953)
pos = nx.kamada_kawai_layout(Gcc)
nx.draw_networkx_nodes(Gcc, pos, ax=ax0, node_size=20, node_color = range(len(Gcc)), cmap=plt.cm.Purples )
nx.draw_networkx_edges(Gcc, pos, ax=ax0, alpha=0.4)
ax0.set_title("Connected components of G")
ax0.set_axis_off()


x_line = [G_3.number_of_nodes() ,G_2.number_of_nodes()]
y_line = [y_3, y] 
ax.axline(xy1 = (x_line[0], y_line[0]), xy2=(x_line[1] , y_line[1]), color='C0', label='by slope', linestyle='--')
ax.set_xlim(1, 100000000)
ax.set_ylim(0, 15)
ax.set_xticks([1, 100, 10000, 1000000, 100000000])
ax.set_yticks([0, 5, 10 ,15])
ax.set_xscale('log')
ax.set_title("Degree Rank Plot")
ax.set_ylabel("Degree")
ax.set_xlabel("Rank")
plt.show()
# ax1 = fig.add_subplot(axgrid[3:, :2])
# ax1.plot(degree_sequence, "b-", marker="o")
# ax1.set_title("Degree Rank Plot")
# ax1.set_ylabel("Degree")
# ax1.set_xlabel("Rank")

ax2 = fig.add_subplot(axgrid[3:, 1:3])
degree_list = list(G_2.degree())
new_degree_list = list(map(lambda x: x[1], degree_list))
counts,bin_edges = np.histogram(new_degree_list, bins = 16, density=True)
bin_centres = (bin_edges[:-1] + bin_edges[1:])/2.
ax2.scatter(bin_centres, counts, marker='*', c = 'purple')
lin = np.arange(0, 35)
ax2.plot(lin, poisson.pmf(lin, mu= 15), c='black')
ax2.set_title("Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")
ax2.set_xticks(np.arange(0, 35, 5))

ax3 = fig.add_subplot(axgrid[3:, 2:3])
ax3.plot(10000,diameter)


fig.tight_layout()
# plt.savefig('first.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 degree_sequence = sorted((d for n, d in G.degree()), reverse=True)
#       2 dmax = max(degree_sequence)
#       4 fig = plt.figure("Degree of a random graph", figsize=stdfigsize(nrows=2, ncols=2))
#
# NameError: name 'G' is not defined

# %%
# Gcc = G.subgraph(sorted(nx.connected_components(G), key=len, reverse=True)[0])
# nx.write_gpickle(Gcc, 'Gcc.gpickle')
# pos = nx.kamada_kawai_layout(Gcc)
# nx.write_gpickle(pos, 'draw-pos.gpickle')

# %%
avg_path = load('/home/carlos/Downloads/facebook_clean_data/avg_path.joblib')

# %%
ln_n = load('/home/carlos/Downloads/facebook_clean_data/ln_n.joblib')

# %%
mosaic = 'AAAA;AAAA;AAAA;BBCC;BBCC;DD..;DD..'
fig = plt.figure(constrained_layout=True, figsize=stdfigsize(nrows = 2 ,ncols=2))
ax_dict = fig.subplot_mosaic(mosaic)

degree_sequence = sorted((d for n, d in G.degree()), reverse=True)
dmax = max(degree_sequence)
Gcc = nx.read_gpickle('Gcc.gpickle')
# Gcc = G.subgraph(sorted(nx.connected_components(G), key=len, reverse=True)[0])
# pos = nx.kamada_kawai_layout(Gcc, seed=10396953)
# pos = nx.kamada_kawai_layout(Gcc)
pos = nx.read_gpickle('draw-pos.gpickle')
nx.draw_networkx_nodes(Gcc, pos, ax=ax_dict['A'], alpha=.8,node_size=30, node_color = range(len(Gcc)), cmap=plt.cm.Purples )
nx.draw_networkx_edges(Gcc, pos, ax=ax_dict['A'], alpha=.4)
ax_dict['A'].set_title("Connected components of G")
ax_dict['A'].set_axis_off()


degree_list = list(G_2.degree())
new_degree_list = list(map(lambda x: x[1], degree_list))
counts,bin_edges = np.histogram(new_degree_list, bins = 16, density=True)
bin_centres = (bin_edges[:-1] + bin_edges[1:])/2.
ax_dict['B'].scatter(bin_centres, counts, marker='*', c = 'purple')
lin = np.arange(0, 35)
ax_dict['B'].plot(lin, poisson.pmf(lin, mu= 15), c='black', label='Poisson \nDistribution', alpha=.7)
ax_dict['B'].set_title("Degree histogram")
ax_dict['B'].set_xlabel("Degree")
ax_dict['B'].set_ylabel("# of Nodes")
ax_dict['B'].set_xticks(np.arange(0, 35, 5))
ax_dict['B'].set_ylim(0,)
ax_dict['B'].set_xlim(0,)
ax_dict['B'].legend( loc=[.65, .8], 
                      borderpad=0.3)


x_line = [G_3.number_of_nodes() ,G_2.number_of_nodes()]
y_line = [y_3, y] 
avg_path = np.load('/home/carlos/Downloads/facebook_clean_data/avg_path.npy')
ln_n = np.load('/home/carlos/Downloads/facebook_clean_data/ln_n.npy')
ln_n = np.log(10**ln_n)

# ax_dict['C'].axline(xy1 = (x_line[0], y_line[0]), xy2=(x_line[1] , y_line[1]), color='black', label='by slope', linestyle='--')
# ax_dict['C'].set_xlim(1, 10)
# ax_dict['C'].set_ylim(0, 15)
# ax_dict['C'].set_xticks([1, 2, 4, 6 , 8, 10])
# ax_dict['C'].set_yticks([0, 5, 10 ,15])
# ax_dict['C'].set_xscale('log')
# ax_dict['C'].set_title("Degree Rank Plot")
# ax_dict['C'].set_ylabel("Degree")
# ax_dict['C'].set_xlabel("Rank")
ax_dict['C'].scatter(ln_n,avg_path)

# %%
y_line[1]
# Out:
# 4.345256021835415
